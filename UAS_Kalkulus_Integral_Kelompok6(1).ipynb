# %% [markdown]
# <a href="https://colab.research.google.com/github/nalarratih/UAS-Kalkulus-Integral-Kelompok6/blob/main/UAS_Kalkulus_Integral_Kelompok6(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Bagian A: Deskripsi Masalah dan Satuan**
# Sebuah kendaraan bergerak di jalan tol selama **T = 100 detik**. Pergerakan dibagi menjadi **4 fase**:
#
# - **Fase 1** (0 ≤ t ≤ 25 s): Akselerasi Linier — v(t) = 2t
# - **Fase 2** (25 < t ≤ 50 s): Konstan — v(t) = 50
# - **Fase 3** (50 < t ≤ 75 s): Akselerasi Kuadratik — v(t) = 50 + (1/25)(t-50)²
# - **Fase 4** (75 < t ≤ 100 s): Deselerasi Linier — v(t) = 75 - 3(t-75)
#
# **Satuan**
# - **Waktu (t):** detik (s)
# - **Kecepatan v(t):** meter/detik (m/s)
# - **Jarak/Akumulasi (s):** meter (m)
#
# ### Tujuan
# Menghitung jarak tempuh total dengan 2 pendekatan, yaitu analitik (SymPy) dan numerik (NumPy trapesium), disertai validasi dan visualisasi per fase.

# %% [markdown]
# ## **Bagian B: Model Matematis**
#
# Fungsi Kecepatan Piecewise v(t)
# $$v(t) = \begin{cases} 2t & 0 \leq t \leq 25 \quad\text{(Fase 1: Akselerasi Linier)}\\ 50 & 25 < t \leq 50 \quad\text{(Fase 2: Konstan)}\\ 50 + 0{,}04(t-50)^2 & 50 < t \leq 75 \quad\text{(Fase 3: Akselerasi Kuadratik)}\\ 75 - 3(t-75) & 75 < t \leq 100 \quad\text{(Fase 4: Deselerasi Linier)} \end{cases}$$
#
# Integral Tentu per Fase
#
# $$s_1 = \int_0^{25} 2t\,dt$$
#
# $$ s_2 = \int_{25}^{50} 50\,dt$$
#
# $$s_3 = \int_{50}^{75}\left[50+0{,}04(t-50)^2\right]dt$$
#
# $$s_4 = \int_{75}^{100}\left[75-3(t-75)\right]dt$$
#
# $$s_{\text{total}} = s_1 + s_2 + s_3 + s_4$$
